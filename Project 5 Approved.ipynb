# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 3</b>
#
#
#     I apologize for deleting them, I deleted them as a way to track which areas i have already taken care of. Thank you for taking the time to review my project, I have left a few comments to better understand where I am lacking or having a difficult time understanding exactly what the question is and how to answer it in code.
#
#     Please feel free to reach out to me on dicord with any comments and helpful tips.
#     Thank you.
#
#
# No worries and thank you very much for such a good job!
#
#
# Here you learned how to prepare raw data for further analysis, how to visualize and interpret data using line charts, box plots, and scatter plots to uncover patterns and correlations, how to build user profiles, formulate and test statistical hypotheses, and draw actionable business conclusions to inform marketing strategies and future planning. Excellent job here! I hope you liked this project.
#
#
# I've left a couple of new comments with digit 3. I also left some code examples. However, there are no issues that need to be fixed, so I can accept the project. Congratulations and good luck! 😊
#
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 2</b>
#
#
# Thank you very much for the updates! Great job here! I've left a few comments titled as **Reviewer's comment 2**. I also noticed that most of the comments I left last time are missing, so I repeated some of them. Would you take a look?
#
# </div>

# %% [markdown]
# <div style="background-color: #e0e0e0; padding: 15px; border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid #a0a0a0;">
# <b> Dear Reviewer </b>
#
#
# I apologize for deleting them,  I deleted them as a way to track which areas i have already taken care of.
#     Thank you for taking the time to review my project, I have left a few comments to better understand where I am lacking or having a difficult time understanding exactly what the question is and how to answer it in code.
#
# Please feel free to reach out to me on dicord with any comments and helpful tips.
#     Thank you.
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment</b>
#
# Hi Leyton, I am a reviewer on this project. Congratulations on submitting the first integrated project! 🎉
#
#
# Before we start, I want to pay your attention to the color marking:
#
#
#
#
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# Great solutions and ideas that can and should be used in the future are in green comments. Some of them are:
#
#
# - You have successfully explored the dataframe. This is an important step, since it helps us identify the issues a dataframe may have and how the distributions look like;
#
#
# - Followed the logical sequence defined in the project description, well done!
#
#
# - You have chosen time interval for further analysis;
#
#
# - Displayed a lot of charts, which is also important, since the results must be easy to interpret;
#
#
# - Conducted statistical tests;
#
#
#
# </div>
#
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
# Yellow color indicates what should be optimized. This is not necessary, but it will be great if you make changes to this project. I've left several recommendations throughout the project. Please take a look.
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
# Issues that must be corrected to achieve accurate results are indicated in red comments. Please note that the project cannot be accepted until these issues are resolved. More specifically:
#
#
#
# - Don't forget to check the data for full and tricky duplicates :)
#
#
#
# - The time interval should be updated as mentioned in one of my comments.
#
#
#
# - In the genres analysis section, please try to use medians as well, since total sales volume is not the best metric to rely on in order to choose the most popular genre.
#
#
#
# - Please add conclusions under each result, this is very important, since we want our results to be interpreted correctly.
#
#
#
# - Please add hypotheses wordings and explain why you choose a specific statistical test and pvalue.
#
#
#
# - Finally, please add more detailes about the regions to the final conclusion. A well-written conclusion shows how the project met its objectives and provides a concise and understandable summary for those who may not have been involved in the details of the project.
#
#
#
# There may be some other small issues that you may find in my comments.
# </div>
# <hr>
#
# <font color='dodgerblue'>**To sum up:**</font> you did a great job here, thank you so much! Actually the project is almost perfect, and the updates should not take much time. If you have any questions, please feel free to ask. I will wait the project for the second review 😊
#
#
# <hr>
#
# Please use some color other than those listed to highlight answers to my comments.
# I would also ask you **not to change, move or delete my comments** to make it easier for me to navigate during the next review.
#
#
#
# <hr>
#
#
# ✍️ Please, check out these two articles about pvalue: [Statisticians issue warning over misuse of P values](https://www.nature.com/articles/nature.2016.19503) and [Misuse of p-values](https://en.wikipedia.org/wiki/Misuse_of_p-values). They are quite important because sometimes pvalue is interpreted incorrectly.
#
#
# [This article](https://www.scribbr.com/statistics/statistical-tests/) gives a cursory understanding of which test to choose. You may find it useful.
#
# <hr>
#
# 📌 Please feel free to schedule a 1:1 sessions with our tutors or TAs, book 1-1 session [here](https://calendly.com/tripleten-ds-experts-team), join daily coworking sessions, or ask questions in the sprint channels on Discord if you need assistance 😉
# </div>

# %% [markdown]
# # Video Game Sales Analysis Project
# ## Project Overview
#
# In this project, you'll analyze video game sales data to identify patterns that determine a game's success. Working as an analyst for the online store Ice, you'll use this information to help plan future advertising campaigns.
#
# ## Environment Setup and Required Libraries

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment</h2>
#
# There's an introduction, which is good. It is important to write an introductory part, because it gives an idea about the content of the project.
#
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Step 1: Loading and Initial Data Exploration
#
# First, let's load our dataset and examine its basic properties:

# %%
 
games = pd.read_csv("/datasets/games.csv")
df = games.round(2)

# %%
display("games Head:")
display(df.head())

display("games Info:")
display(df.info())
# Out:
# 'games Head:'
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN
# 'games Info:'
# <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment</h2>
#
# The data was successfully read, well done!
#
# </div>

# %% [markdown]
# ### Key Questions to Answer:
# - What's the total number of records in our dataset?
# - What data types are present in each column?
# - Are there any obvious issues with the data?
# - Do we see any immediate patterns or anomalies?

# %% [markdown]
# ## Step 2: Data Preparation
#
# ### 2.1 Standardizing Column Names

# %%
df.columns = df.columns.str.lower()

# %% [markdown]
# ### 2.2 Data Type Conversion

# %%
df['year_of_release'] = df['year_of_release'].fillna(0).astype(int)
df['critic_score'] = df['critic_score'].fillna(0).astype(int)

# %%
df['user_score'] = df['user_score'].replace('tbd', None)

# %% [markdown]
# ### 2.3 Handling Missing Values

# %%
df['user_score'] = pd.to_numeric(df['user_score'], errors='coerce')

# %%
df['user_score'] = df['user_score'].fillna("0.0")

# %%
df['rating'] = df['rating'].fillna('Unknown')

# %%
duplicate_count = df['name'].duplicated().sum()
print(f"Total duplicate names: {duplicate_count}")
# Out:
# Total duplicate names: 5155

# %%
# df['name'] = df.groupby('name').cumcount().astype(str).replace('0', '', regex=False) + df['name']

# display(df.head())

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b> Notes so far </b>
#
# Above,  I have cchanged the columns all to lower case, as well as converted them to only 2 decimals. replaced "tbd" and missing values to 0.
# This will make it easier to get the best updates. Seeing as there is no reason so far deermined as to why some of the information may be missing, unless it was just sold it that country alone.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment</h2>
#
# Yes, we can do this. Filling in the gaps with some strange value is an appropriate solution. It's much safer than trying to replace them with mode or median. At the same time, we can ignore the gaps and leave them as is.
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment</h2>
#
#
# However, we should always make sure the data does not have the values we are using to replace the gaps.
# </div>

# %% [markdown]
# <div style="background-color: #e0e0e0; padding: 15px; border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid #a0a0a0;">
# <b> Dear Reviewer </b>
#
# Do i check for this by seeing if their are duplicate names and release year, and then the ones that have missing ratings make them equal to that of the similar name?
# or os this just a "heads up for future reference"?
# </div>

# %% [markdown]
# ### 2.4 Calculate Total Sales

# %%
# Calculate total sales across all regions and put them in a different column

# %%
df['total_sales'] = df[['na_sales', 'eu_sales', 'jp_sales', 'other_sales']].sum(axis=1)

sorted_sales = df.sort_values(by='total_sales', ascending=False)

display(sorted_sales.head(9))
# Out:
#                         name platform  year_of_release         genre  \
# 0                 Wii Sports      Wii             2006        Sports
# 1          Super Mario Bros.      NES             1985      Platform
# 2             Mario Kart Wii      Wii             2008        Racing
# 3          Wii Sports Resort      Wii             2009        Sports
# 4   Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# 5                     Tetris       GB             1989        Puzzle
# 6      New Super Mario Bros.       DS             2006      Platform
# 7                   Wii Play      Wii             2006          Misc
# 8  New Super Mario Bros. Wii      Wii             2009      Platform
#
#    na_sales  eu_sales  jp_sales  other_sales  critic_score user_score  \
# 0     41.36     28.96      3.77         8.45            76        8.0
# 1     29.08      3.58      6.81         0.77             0        0.0
# ...

# %%
games_after_2007 = df[df['year_of_release'] > 2007].copy()

games_after_2007['total_sales'] = games_after_2007[['na_sales', 'eu_sales', 'jp_sales', 'other_sales']].sum(axis=1)

sorted_sales_after_2007 = games_after_2007.sort_values(by='total_sales', ascending=False)

display(sorted_sales_after_2007.head(9))
# Out:
#                               name platform  year_of_release         genre  \
# 2                   Mario Kart Wii      Wii             2008        Racing
# 3                Wii Sports Resort      Wii             2009        Sports
# 8        New Super Mario Bros. Wii      Wii             2009      Platform
# 14              Kinect Adventures!     X360             2010          Misc
# 15                    Wii Fit Plus      Wii             2009        Sports
# 16              Grand Theft Auto V      PS3             2013        Action
# 23              Grand Theft Auto V     X360             2013        Action
# 27     Pokemon Black/Pokemon White       DS             2010  Role-Playing
# 29  Call of Duty: Modern Warfare 3     X360             2011       Shooter
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score user_score  \
# 2      15.68     12.76      3.79         3.29            82        8.3
# 3      15.61     10.93      3.28         2.95            80        8.0
# ...

# %%
duplicate_game_names = sorted_sales_after_2007[sorted_sales_after_2007.duplicated(subset=['name', 'platform', 'year_of_release'], keep=False)]
display(duplicate_game_names)
# Out:
#                 name platform  year_of_release   genre  na_sales  eu_sales  \
# 604    Madden NFL 13      PS3             2012  Sports      2.11      0.22
# 16230  Madden NFL 13      PS3             2012  Sports      0.00      0.01
#
#        jp_sales  other_sales  critic_score user_score rating  total_sales
# 604         0.0         0.23            83        5.5      E         2.56
# 16230       0.0         0.00            83        5.5      E         0.01

# %%
sorted_sales_after_2007 = sorted_sales_after_2007.drop(16230)

# %%
duplicate_game_names = sorted_sales_after_2007[sorted_sales_after_2007.duplicated(subset=['name', 'platform', 'year_of_release'], keep=False)]
display(duplicate_game_names)
# Out:
# Empty DataFrame
# Columns: [name, platform, year_of_release, genre, na_sales, eu_sales, jp_sales, other_sales, critic_score, user_score, rating, total_sales]
# Index: []

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b> Notes so far </b>
#
# Above, I have seen the largest sales was in 2006 with Wii sports leading in sales. However looking what the Data has told us within the past 10 years was in 2008 with Mario Kart Wii leading.
# </div>

# %% [markdown]
# <div style="background-color: #e0e0e0; padding: 15px; border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid #a0a0a0;">
# <b> Dear Reviewer </b>
#
#
# Afer running the code before I ran it for just names and thought it was just a comment as a "for future reference" duplicates of the same game came up in which i thought was typical due to it ws released on several different platforms. so i changed their names, which then made it harder when in the later parts of the project it asks for the games released across multi platforms. thus i deleted the code and your comment to not mess me up.
#
# After your 2nd review, I had checked again to see if there were any duplicates on the same platform. thus i saw the Madden game, in which it was the same game, same release year, completely difference stat,  so i deleted the 2nd duplicate, checked again that it was deleted, and moved on.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3</h2>
#
# Understood! :)
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
#
# I see my comment about the duplicates is missing. Let me repeat it:
#
#
# - Please do not forget to check data for the duplicates.
#
#
# - There may be unobvious duplicates in the data, or duplicates in multiple columns. For example, there may be rows that have the same game's name, genre, year of release, platform and age rating, but they may have different user scores for some reason. Try to find them in columns `'name', 'platform', 'year_of_release'`, for instance.
#
#
# Imagine you are looking for the duplicates in the dataframe:
#
# ```python
#
# John Smith 35
#
# John Smith 8
#
# John Adams 21
# ```
#
#
# There are three columns: first name, last name, and age. If we apply `duplicated` to this dataframe, we will not find any duplicates, since at least one of the values differs. However, if we try to find `'first name' - 'last name'` duplicates, we will notice that there are two people with the same full name, John Smith.
#
#
# Apply the same logic and try to look for the `'name'-'platform'-'year_of_release'` duplicates. The `subset` parameter should help you. As a subset, use the list of columns: `subset=['name', 'platform', 'year_of_release]`.</div>

# %% [markdown]
# # Step 3: Analyzing Video Game Sales Data
#
# ## 3.1 Temporal Analysis of Game Releases
# Let's first examine the distribution of game releases across different years to understand our data's coverage and significance:

# %%
games_per_year = sorted_sales_after_2007['year_of_release'].value_counts().sort_values(ascending=False)

display(games_per_year.head(9))
# Out:
# 2008    1427
# 2009    1426
# 2010    1255
# 2011    1136
# 2012     652
# 2015     606
# 2014     581
# 2013     544
# 2016     502
# Name: year_of_release, dtype: int64

# %%
# Visualize the distribution of games across years
# Display summary statistics for each year

# %%
games_per_year = sorted_sales_after_2007['year_of_release'].value_counts().sort_index()

plt.figure(figsize=(12, 6))
sns.barplot(x=games_per_year.index, y=games_per_year.values, palette='viridis')

plt.title('Distribution of Games Released Per Year', fontsize=16)
plt.xlabel('Year of Release', fontsize=12)
plt.ylabel('Number of Games Released', fontsize=12)

plt.xticks(rotation=45)
plt.show()

# %%
next_gen = sorted_sales_after_2007[sorted_sales_after_2007['year_of_release'] >= 2013].copy()
games_per_year = next_gen['year_of_release'].value_counts().sort_index()

plt.figure(figsize=(12, 6))
sns.barplot(x=games_per_year.index, y=games_per_year.values, palette='viridis')

plt.title('Distribution of Games Released Per Year', fontsize=16)
plt.xlabel('Year of Release', fontsize=12)
plt.ylabel('Number of Games Released', fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b> Notes so far </b>
#
# I have narrowed it down to next generation platforms seeing as that is what we will most likely be working with.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment </h2>
#
# Nice chart! It's great that you add a title with axes labels.
#
# </div>

# %% [markdown]
# ### Questions to Consider:
# - Which years show significant numbers of game releases?
# - Are there any notable trends or patterns in the number of releases?
# - Is there enough recent data to make predictions for 2017?

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b> Notes so far </b>
#
# 1. 2008 showed the most significant in games released within the past 10 years
#
# 2. After 2011, games gradually decreased is released count.
#
# 3. Yes, Through the advances in technology and graphics, platforms no longer need to release more games rather than just add to games.  The advancement in being able to add graphic updates, and DLCs, and patch updates where the same games are run, but there are many changes has come a long way for developers.
# </div>

# %% [markdown]
# ## 3.2 Platform Sales Analysis Over Time
#
# Now let's analyze how sales vary across platforms and years:

# %%
# Calculate total sales by platform and year

# %%
platform_releases = next_gen.groupby(['platform', 'year_of_release']).size().reset_index(name='count')

platform_releases_sorted = platform_releases.sort_values(by=['count', 'year_of_release'], ascending=[False, True])

display(platform_releases_sorted.head(9))
# Out:
#    platform  year_of_release  count
# 16      PS4             2016    164
# 15      PS4             2015    137
# 9       PS3             2013    126
# 22      PSV             2015    110
# 10      PS3             2014    108
# 21      PSV             2014    100
# 0       3DS             2013     91
# 39     XOne             2016     87
# 2       3DS             2015     86

# %%
# Create a heatmap of platform sales over time

# %%
platform_sales_pivot = platform_releases_sorted.pivot(index='platform', columns='year_of_release', values='count').fillna(0)

plt.figure(figsize=(16, 10))
sns.heatmap(platform_sales_pivot, cmap='viridis', annot=False, fmt='.0f', linewidths=0.5)

plt.title('Heatmap of Platform Games Released Over Time', fontsize=16)
plt.xlabel('Year of Release', fontsize=12)
plt.ylabel('Platform', fontsize=12)

plt.show()

# %%
# Identify platforms with declining sales

# %%
platform_sales = next_gen.groupby(['platform', 'year_of_release'])['total_sales'].sum().reset_index()
platform_totals = platform_sales.groupby('platform')['total_sales'].sum()
valid_platforms = platform_totals[platform_totals >= 70].index
platform_sales = platform_sales[platform_sales['platform'].isin(valid_platforms)]

platform_sales_pivot = platform_sales.pivot(index='year_of_release', columns='platform', values='total_sales').fillna(0)

plt.figure(figsize=(16, 10))
sns.lineplot(data=platform_sales_pivot, dashes=False, palette="tab10")  # Use 'tab10' for better distinction

plt.title('Platform Sales Trends Over Time)', fontsize=16)
plt.xlabel('Year of Release', fontsize=12)
plt.ylabel('Total Sales (in millions)', fontsize=12)

plt.legend(title='Platform', fontsize=10, loc='upper left')
plt.show()

# %%
#filtered_sales = platform_sales[platform_sales['year_of_release'] > 2012]

#platform_sales = filtered_sales.groupby(['platform', 'year_of_release'])['total_sales'].sum().reset_index()

#platform_sales_pivot = platform_sales.pivot(index='year_of_release', columns='platform', values='total_sales').fillna(0)

#platform_sales_pivot.plot(kind='bar', stacked=True, figsize=(16, 10), colormap='plasma')

#plt.title('Platform Sales Trends Over Time)', fontsize=16)
#plt.xlabel('Year of Release', fontsize=12)
#plt.ylabel('Total Sales (in millions)', fontsize=12)

#plt.legend(title='Platform', fontsize=10, loc='upper left', bbox_to_anchor=(1, 1))
#plt.tight_layout()
#plt.show()

# %%
filtered_sales = df[df['year_of_release'] >= 2013].copy()

platform_sales = filtered_sales.groupby(['platform', 'year_of_release'])['total_sales'].sum().reset_index()

platform_sales_pivot = platform_sales.pivot(index='year_of_release', columns='platform', values='total_sales').fillna(0)

platform_sales_pivot.plot(kind='line', stacked=True, figsize=(16, 10), colormap='tab10')

plt.title('Platform Sales Trends Over Time)', fontsize=16)
plt.xlabel('Year of Release', fontsize=12)
plt.ylabel('Total Sales (in millions)', fontsize=12)

plt.legend(title='Platform', fontsize=10, loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment</h2>
#
#
# The bar chart looks very nice! It's great that you use different color maps!
#
#
# </div><div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
#
# However, consider either using a line chart or reducing the number of platforms because it is impossible to distinguish PSP from PS4 on the chart above.
# </div>

# %% [markdown]
# <div style="background-color: #e0e0e0; padding: 15px; border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid #a0a0a0;">
# <b> Dear Reviewer </b>
#
# I have made the splice to the original data. As well a turned it into a line chart in the 2nd graph, and did different coloring
# </div>

# %% [markdown]
# ### Questions to Consider:
# - Which platforms show consistent sales over time?
# - Can you identify platforms that have disappeared from the market?
# - What's the typical lifecycle of a gaming platform?

# %% [markdown]
# <div class="alert alert-block alert-info">
# <B> Updated Notes so far: </B>
#
# 1. Xbox One and PS4 have been consisten with highest sales for Xbox,  and PS4 slowly climbing the ranks as PS3 dwindles lower.
#
# 2. the 3DS, DS, Wii, have dwindled in sales going lower each year. They generally start becoming lower once new generation consoles come, and to keep up with new games and advancements.
#
# 3. Typical lifecycle of a platform has been Releasing new games and everyone buys,  and then the game dwindles over time.  until newer platform genertions come out with newer games and more advanced in game play, graphics, and adaptability with the way people are playing games now. the average lifespans of a platform are based on their ability to adapt to new technologies and advancements.
# </div  >

# %% [markdown]
# <div style="background-color: #e0e0e0; padding: 15px; border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid #a0a0a0;">
# <b> Dear Reviewer </b>
#
# I'm confused with your 2nd comments,  In my notes so far above I thought I had answered the questions outlined.
#
# The other thing I'm assuming you are looking for is for me to take out the ">= 2013" and see the growth since the beginning and see how long it took for platforms to just suddenly drop (like went out of business)
#
# I have made the Splice (though still grabbing just the recent years)
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3</h2>
#
# We need to explicitly state this in our conclusions. If our results are misinterpreted, decision makers may make incorrect choices. Therefore, we must present our findings in a way that ensures every reader understands them accurately. We can display the following pivot table:
#
# </div>

# %%
# Reviewer's code 3 

filtered_sales.pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')
# Out:
# platform           3DS    DS     PC     PS3     PS4   PSP    PSV   Wii   WiiU  \
# year_of_release
# 2013             56.57  1.54  12.38  113.25   25.99  3.14  10.59  8.59  21.65
# 2014             43.76   NaN  13.28   47.76  100.00  0.24  11.90  3.75  22.03
# 2015             27.78   NaN   8.52   16.82  118.90  0.12   6.25  1.14  16.35
# 2016             15.14   NaN   5.25    3.60   69.25   NaN   4.25  0.18   4.60
#
# platform          X360   XOne
# year_of_release
# 2013             88.58  18.96
# 2014             34.74  54.07
# 2015             11.96  60.14
# 2016              1.52  26.15

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3</h2>
#
# Here we see that DS and PSP that used to be very popular are not even supported now. The sales of PS3 and X360 games (another pair of famous platforms) have significantly decreased and go to zero. These platforms, although some people still use them, should not be considered promising and we should not use them in marketing.
#
#
# PS4 and XOne are the most promising. I would also take 3DS into account, as it still has a large sales volume. Remember that we represent sales of the games released these years. Not sold but released. The 2014-2016 games haven't gained such volumes yet as, for instance, 2012 games have.
#
#
# PC may also be a good choice, since people either use a gaming console or a PC.
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 </h2>
#
#
# > `filtered_sales = platform_sales[platform_sales['year_of_release'] > 2012]`
#
#
# Agreed! It's a good choice for the following three reasons:
#
#
#
# 1. Years before 2012 have huge sales volume, which can influence our distributions.
#
#
# 2. New platforms appeared in 2012-2013, which means that these huge sales were generated by older platforms that cannot be relevant for so many years.
#
# 3. Since graphics and other components change fast, users' preferences change as well. It means that most people had different perceptions 10 years ago compared to their current perception.
#
#
#
#
# </div><div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
#
# - So which platforms used to be popular but now have zero or almost zero sales? How long does it generally take for new platforms to appear and old ones to fade? Please don't forget to answer the questions please from the task :)
#
#
#
#
# - What is the average lifespan?
#
#
# - Please notice that `platform_sales` is a pivot table. As a result, `filtered_sales` is also a pivot table. You need to make a slice from the original dataframe instead.
#
# </div>

# %% [markdown]
# ## 3.3 Determining Relevant Time Period
#
# Based on your analysis above, determine the appropriate time period for predicting 2017 sales:

# %%
sales_by_year_platform = filtered_sales.groupby(['year_of_release', 'platform'])['total_sales'].sum().reset_index()

sales_by_year_platform_sorted = sales_by_year_platform.sort_values(by=['total_sales'], ascending=False)

top_3_years = sales_by_year_platform_sorted.head(9)
print(top_3_years)
# Out:
#     year_of_release platform  total_sales
# 24             2015      PS4       118.90
# 3              2013      PS3       113.25
# 14             2014      PS4       100.00
# 9              2013     X360        88.58
# 34             2016      PS4        69.25
# 30             2015     XOne        60.14
# 0              2013      3DS        56.57
# 20             2014     XOne        54.07
# 13             2014      PS3        47.76

# %% [markdown]
# ### Document Your Decision:
# - What years did you select and why?
# - How does this period reflect current market conditions?
# - What factors influenced your decision?

# %% [markdown]
# <div class="alert alert-block alert-info">
# <B> Notes: </B>
#
# * In the past 5 years <b>Playstation</b> dominated with sales 3 years in a row, top sales being in 2015.
# My conclusion is that the Playstation graphics have come a long way in advancement that it has demolished in graphics.
#
#
# * 2015 reflects 207 greatly We see that in earlier years New games being released is what drove sales along with high ratings. But sales dwindled on games as new games were developed and released.  Once 2013 hit and next geeration consoles came out sales for earlier versions and their games deminished over time. 2015 seems to be a perfect time period to focus on seeing s the latests generation consoles are out and we can monitor the games released and how they progress until a newer generation console comes out.
#
#
# * I came to this conclusion due to its irrelevant to focus on past sales other than how history demonstrates user actions. focusing on the past 10 years i had narrowed my time down to 2013 and after seeing as that is where we have the next generation gaming coming to life. 2015 is a few years into it to give us the history of how things have been since their release as well as buyer reviews and ratings.
#
#     (PS4, PS3, Xbox One, Xbox 360, and the 3DS seem to be very promising!)
# </div  >

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3</h2>
#
# Good! You can also check out my previous comment, where I explained why some of these platforms should not be called promising.
#
#
# </div><div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
#
# What platforms can be called promising?
#
# </div>

# %% [markdown]
# ## 3.4 Platform Performance Analysis
#
# Using your selected time period, let's analyze platform performance:

# %%
# Analyze platform sales trends

# %%
# Sort platforms by total sales

# %%
# Visualize top platforms
# Calculate year-over-year growth for each platform
# Your code here to calculate and visualize platform growth rates

# %%
platform_sales = filtered_sales.groupby(['platform', 'year_of_release'])['total_sales'].sum().reset_index()

total_sales_by_platform = platform_sales.groupby('platform')['total_sales'].sum().sort_values(ascending=False).reset_index()

plt.figure(figsize=(12, 6))
sns.barplot(data=total_sales_by_platform.head(10), x='total_sales', y='platform', palette='Set2')
plt.title('Top Platforms by Total Sales', fontsize=16)
plt.xlabel('Total Sales (in millions)', fontsize=12)
plt.ylabel('Platform', fontsize=12)
plt.show()

platform_sales['yearly_growth'] = platform_sales.groupby('platform')['total_sales'].pct_change()

plt.figure(figsize=(16, 8))
for platform in platform_sales['platform'].unique():
    platform_data = platform_sales[platform_sales['platform'] == platform]
    plt.plot(platform_data['year_of_release'], platform_data['yearly_growth'], label=platform)

plt.title('Year-over-Year Growth by Platform', fontsize=16)
plt.xlabel('Year of Release', fontsize=12)
plt.ylabel('Year-over-Year Growth (%)', fontsize=12)
plt.legend(title='Platform', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <B> Conclusion: updated</B>
#
# * Playstation 4 has top sales, followed by Xbox 1 and 3DS.
#
# * Year to Year growth has been a steady decline for all platforms except for PSV which has gradually been getting more poplar through the years.
#
# *  PC has stayed at a stedy Neutral
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
#
# The results will change when you update the slice.
# </div>

# %% [markdown]
# <div style="background-color: #e0e0e0; padding: 15px; border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid #a0a0a0;">
# <b> Dear Reviewer </b>
#
#
# I attended a tutors live hours to review my code before submitting a 3rd time, I wanted to make sure the slice worked appropriately.  However i was concerned as you mentioned these numbers would change.  after the slice and the tutors looked over, he explained it looked good. If there is something I'm not understanding please reach out to me.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3</h2>
#
# In some of the code cells, the incorrect slice was used. That is why I left this comment.
#
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3</h2>
#
# It may be hard to compare the lines above. Consider descreasing the range of the Y axis values. In addition, it may be a good idea to represent years as integers.
#
# </div>

# %% [markdown]
# ## 3.5 Sales Distribution Analysis
#
# Let's examine the distribution of sales across platforms:

# %%
# Create box plot of sales by platform

# %%
filtered_sales.boxplot('total_sales', by='platform', figsize=(12,7))
plt.ylim(0,3)

plt.title('Total Sales Platform (2015)', fontsize=16)
plt.xlabel('Platform', fontsize=12)
plt.ylabel('Total Sales (in millions)', fontsize=12)
plt.ylim(0,3)

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
# - Actually, we don't need to group by year here, the idea is to show the distribution (boxplot show the distribution) of the sales for each platform, taking into account every single game. So we just need to group by platform, that's all.
#
#
#
# - Please don't take one year. Instead, analyze teh chosen period.
#
#
# - It may be difficult to compare the boxes. Please, try to use the **ylim** (`plt.ylim(0,3)`), it will scale the graph.
#
#
# - There will be some outliers there, don't drop them. What do you think outliers can tell us? Just write any suggestions you have.
#
#
# You can use the following code:
#
# ```python
# relevant_data.boxplot('total_sales', by='platform', figsize=(12,7))
# plt.ylim(0,3)
#
# ```
# </div>

# %% [markdown]
# <div style="background-color: #e0e0e0; padding: 15px; border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid #a0a0a0;">
# <b> Dear Reviewer </b>
#
# Hope that is what you meant.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3</h2>
#
# Exactly! Now we can easily interpret the results! A boxplot shows us a distribution, like a histogram. 2 pictures below represent it:
#
#
# ![image info](https://r-charts.com/en/distribution/histogram-boxplot_files/figure-html/histogram-boxplot.png)
#
#
# ![image.png](https://i.ytimg.com/vi/FPREzlHdWRY/maxresdefault.jpg)
#
#
#
# But the boxplot is better, since we don't have to think about `bins` parameter for a histogram. Boxplot also shows us some statistics, while histogram doesn't.
#
#
# What does our boxplot tell us about? Since we are plotting sum world sales per game, outliers are just some very popular games. I would even say bestsellers. And this is a very illustrative thing. Look at the 3DS. Small box and lots of outliers. This suggests that a large part of the sales volume comes from these outliers. At the same time, the XOne has a different situation: a large box, a long whisker and few outliers. This indicates that a wide variety of games are bought on XOne, and, moreover, in considerable quantities.
#
# That's why it may be useful to plot 2 graphs: with and without outliers. Just to evaluate the distribution.
#
# That's how you can interpret boxplots.
#
# </div>

# %%
# Calculate detailed statistics for each platform

# %%
platform_stats = filtered_sales.groupby('platform')['total_sales'].agg(['mean', 'median', 'std', 'sum', 'count']).reset_index()

platform_stats.rename(columns={
    'mean': 'Average Sales',
    'median': 'Median Sales',
    'std': 'Standard Deviation',
    'sum': 'Total Sales',
    'count': 'Number of Games'
}, inplace=True)

display(platform_stats)
# Out:
#    platform  Average Sales  Median Sales  Standard Deviation  Total Sales  \
# 0       3DS       0.472772         0.090            1.381347       143.25
# 1        DS       0.192500         0.150            0.172026         1.54
# 2        PC       0.208624         0.080            0.352304        39.43
# 3       PS3       0.525884         0.150            1.451939       181.43
# 4       PS4       0.801378         0.200            1.609456       314.14
# 5       PSP       0.052239         0.020            0.059768         3.50
# 6       PSV       0.092151         0.040            0.153816        32.99
# 7       Wii       0.593913         0.180            0.915432        13.66
# 8      WiiU       0.562000         0.200            1.038778        64.63
# 9      X360       0.735484         0.265            1.663275       136.80
# 10     XOne       0.645020         0.220            1.036139       159.32
#
#     Number of Games
# 0               303
# 1                 8
# ...

# %% [markdown]
# ## 3.6 Review Score Impact Analysis
#
# Select a popular platform and analyze how reviews affect sales:

# %%
# Choose a popular platform based on your previous analysis

# %%
ps_games = filtered_sales[filtered_sales['platform'] == 'PS4']
best_ps_games = ps_games[ps_games['critic_score'] > 70]
filtered_data = best_ps_games.dropna(subset=['critic_score', 'total_sales'])
display(filtered_data.head(9))
# Out:
#                                        name platform  year_of_release  \
# 42                       Grand Theft Auto V      PS4             2014
# 77                                  FIFA 16      PS4             2015
# 92           Call of Duty: Advanced Warfare      PS4             2014
# 94                                  FIFA 17      PS4             2016
# 105                               Fallout 4      PS4             2015
# 143                                 FIFA 15      PS4             2014
# 154                                 Destiny      PS4             2014
# 171              Uncharted 4: A Thief's End      PS4             2016
# 231  Uncharted: The Nathan Drake Collection      PS4             2015
#
#             genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 42         Action      3.96      6.31      0.38         1.97            97
# 77         Sports      1.12      6.12      0.06         1.28            82
# ...

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3 </h2>
#
# > `filtered_data = best_ps_games.dropna(subset=['critic_score', 'total_sales'])`
#
# There are rows that have users' scores and do not have critics' score and vice versa. If you delete rows that have Nan in any of these two columns, you may lose data. So it's better to create separate dataframes here: one for critics' scores analysis and one for users' scores analysis.
#
#
# Let's think about it for a moment. Imagine you have a dataframe:
# </div>

# %%
# Reviewer's code 3.1

l = {'critic_score':[1,0,4, 0], 'user_score':[3,3,0, 0]}

ddf = pd.DataFrame(l)

ddf
# Out:
#    critic_score  user_score
# 0             1           3
# 1             0           3
# 2             4           0
# 3             0           0

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3</h2>
#
# If we apply a condition with `&` and remove zeros from both columns, we lose rows #1 and #2. Row #1 has a user_score value, while row #2 has a critic_score value. In other words, we lose information. Take a look:
# </div>

# %%
# Reviewer's code 3.2

ddf[(ddf['critic_score'] != 0) & (ddf['user_score'] != 0)]
# Out:
#    critic_score  user_score
# 0             1           3

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3</h2>
#
# We can use logical OR here, but since we do it inside one dataframe, we will display some of these zeros. Same issue happens to the missing values.
#
#
# In order to do everything correctly and not lose important information, we have to create two dataframes separately.
#
# </div>

# %%
# Create scatter plots for both critic and user scores

# %%
# Critic Scores
# User Scores
# Calculate correlations

# %%
if not filtered_data.empty:
    filtered_data['critic_score'] = pd.to_numeric(filtered_data['critic_score'], errors='coerce')
    filtered_data['user_score'] = pd.to_numeric(filtered_data['user_score'], errors='coerce')
    filtered_data['total_sales'] = pd.to_numeric(filtered_data['total_sales'], errors='coerce')

    filtered_data = filtered_data.dropna(subset=['critic_score', 'user_score', 'total_sales'])

    plt.figure(figsize=(10, 6))
    sns.scatterplot(data=filtered_data, x='critic_score', y='total_sales', color='blue', label='Total Sales')
    plt.title('Critic Score vs Total Sales (PS4)', fontsize=16)
    plt.xlabel('Critic Score', fontsize=12)
    plt.ylabel('Total Sales (in millions)', fontsize=12)
    plt.legend(title='Legend', fontsize=10)
    max_y = filtered_data['total_sales'].max()
    plt.ylim(0, max_y + 5)
    plt.yticks(np.arange(0, max_y + 5, max_y // 10 if max_y > 10 else 1))
    plt.show()

    correlation = filtered_data['critic_score'].corr(filtered_data['total_sales'])
    print(f"Correlation between Critic Score and Total Sales: {correlation:.2f}")
    
    plt.figure(figsize=(10, 6))
    sns.scatterplot(data=filtered_data, x='user_score', y='total_sales', color='green', label='Total Sales')
    plt.title('User Score vs Total Sales (PS4)', fontsize=16)
    plt.xlabel('User Score', fontsize=12)
    plt.ylabel('Total Sales (in millions)', fontsize=12)
    plt.legend(title='Legend', fontsize=10)
    max_y = filtered_data['total_sales'].max()
    plt.ylim(0, max_y + 5)
    plt.yticks(np.arange(0, max_y + 5, max_y // 10 if max_y > 10 else 1))
    plt.show()

    correlation = filtered_data['user_score'].corr(filtered_data['total_sales'])
    print(f"Correlation between User Score and Total Sales: {correlation:.2f}")
else:
    print("filtered_data is empty. Cannot calculate correlation or plot.")
# Out:
# Correlation between Critic Score and Total Sales: 0.43
# Correlation between User Score and Total Sales: -0.22

# %% [markdown]
# <div class="alert alert-block alert-info">
# <B> Conclusion: </B>
#
# Critic Score - The higher the critic score rating the better the sales for PS4 games in the past 5 years, with a 43% chance of the game selling more with a higher rating.
#
# User Rating - Had no correlation with the score and sales. with a -22 % correlation.
# </div>

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
#
# Everything will change when you update the slice, since we should not work with the grouped data (pivot table).
#
# </div>

# %% [markdown]
# <div style="background-color: #e0e0e0; padding: 15px; border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid #a0a0a0;">
# <b> Dear Reviewer </b>
#
# There was no change after making the splice...  after changing it to the original dataset and asking the tutor to check it, there seems to be no difference in the data in the scatterplots and correlation.
# did i do something wrong?
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3</h2>
#
#
# The correct slice is used now, so everything is great!
# </div>

# %% [markdown]
# ## 3.7 Cross-Platform Comparison
#
# Compare sales performance of games across different platforms:

# %%
# Find games released on multiple platforms

# %%
# Compare sales across platforms for these games
# Your code here to analyze and visualize cross-platform performance

# %%
multi_platform_games = filtered_sales.groupby('name').filter(lambda x: x['platform'].nunique() > 1 and x['total_sales'].sum() > 2)

cross_platform_sales = multi_platform_games.groupby(['name', 'platform'])['total_sales'].sum().reset_index()

top_10_games = cross_platform_sales.groupby('name')['total_sales'].sum().nlargest(10).index
filtered_cross_platform_sales = cross_platform_sales[cross_platform_sales['name'].isin(top_10_games)]

selected_platforms = ['PS4', 'XOne', 'X360', 'PS3', 'DS']
filtered_cross_platform_sales = filtered_cross_platform_sales[filtered_cross_platform_sales['platform'].isin(selected_platforms)]

plt.figure(figsize=(16, 8))
sns.barplot(data=filtered_cross_platform_sales, x='total_sales', y='name', hue='platform', palette='Paired')

plt.title('Top 10 Cross-Platform Sales Performance (Filtered Platforms)', fontsize=16)
plt.xlabel('Total Sales (in millions)', fontsize=12)
plt.ylabel('Game Name', fontsize=12)
plt.legend(title='Platform', fontsize=10, loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <B> Conclusion: </B>
#
# GTA-V had astonishing sales, However,  you can also see a trend that the highest sales go to the Call of Duty games, especially in PS3 and Xbox 360. We can see a trend here that as sequals to popuar games where its similar but adds better graphics, storyline, and variety of different things you can do than they were in the previous version.  (this also helps when customers are familar with a certain control scheme with their preffered games and wantto stick with what they like and are familar with.)
# </div>

# %% [markdown]
# <div style="background-color: #e0e0e0; padding: 15px; border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid #a0a0a0;">
# <b> Dear Reviewer </b>
#
# I narrowed it down to Playstation, Xbox, and DS.
#
# I included both generation systems just to see how the game released on same platform just new generation did.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3</h2>
#
#
# Great! </div>
#
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 </h2>
#
#
# It's better to choose 2-3 promising platforms and compare them than to display everything on one chart. You chose very good platforms: recent platforms that may interest a reader. However, сombining multiple platforms into a single dataframe for scatter plot and correlation analysis may lead to misleading results. Each platform may have significantly different market dynamics, user demographics, and sales behavior. When merged, these differences can cancel each other out or mask true trends, making it difficult to draw clear conclusions.
#
# For example, a high critic score might strongly influence sales on PS4 but have minimal impact on 3DS. If analyzed together, these effects could average out, suggesting there's no clear relationship between critic score and sales, even though such relationship exists, just in different ways for each platform.
#
# By analyzing each platform individually, you will maintain the integrity of the data and may uncover platform-specific insights that would otherwise be hidden. This leads to more accurate interpretations and better decision-making. Consider analyzing them separately.
#
# </div>

# %% [markdown]
# ## 3.8 Genre Analysis
#
# Finally, let's examine the distribution of games by genre:

# %%
# Analyze genre performance
# Sort genres by total sales
# Visualize genre distribution
# Calculate market share for each genre

# %%
genre_sales = filtered_sales.groupby('genre')['total_sales'].sum().reset_index()

genre_sales_sorted = genre_sales.sort_values(by='total_sales', ascending=False)

print(genre_sales_sorted)
# Out:
#            genre  total_sales
# 0         Action       321.87
# 8        Shooter       232.98
# 10        Sports       150.65
# 7   Role-Playing       145.89
# 3           Misc        62.82
# 4       Platform        42.63
# 6         Racing        39.89
# 2       Fighting        35.31
# 1      Adventure        23.64
# 9     Simulation        21.76
# 11      Strategy        10.08
# 5         Puzzle         3.17

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2</h2>
#
# Good!
#
# </div><div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
# Please use relevant time interval, the one you chose above that starts from 2013. Some popular genre may not remain popular 10 years later. And vice versa. During this time, several platform generations will change :) The industry is evolving, the games are getting better, the graphics is getting better and the users are getting more demanding. In such tasks, we need fresh information, fresh estimation. If we forecast for 2017, then who cares what happened 10 years ago? :)
#
#
# </div>

# %% [markdown]
# <div style="background-color: #e0e0e0; padding: 15px; border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid #a0a0a0;">
# <b> Dear Reviewer </b>
#
# Filtered_sales should be set to anything older that 2013
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3</h2>
#
#
# Correct.
# </div>

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=genre_sales_sorted, x='total_sales', y='genre', palette='viridis')

plt.title('Total Sales by Genre', fontsize=16)
plt.xlabel('Total Sales (in millions)', fontsize=12)
plt.ylabel('Genre', fontsize=12)

plt.show()

# %%
total_sales = genre_sales_sorted['total_sales'].sum()

genre_sales_sorted['market_share'] = (genre_sales_sorted['total_sales'] / total_sales) * 100

print(genre_sales_sorted[['genre', 'market_share']])

plt.figure(figsize=(10, 8))
plt.pie(
    genre_sales_sorted['market_share'], 
    labels=genre_sales_sorted['genre'], 
    autopct='%1.1f%%', 
    startangle=140, 
    colors=sns.color_palette('viridis', len(genre_sales_sorted))
)

plt.title('Market Share by Genre', fontsize=16)

plt.show()
# Out:
#            genre  market_share
# 0         Action     29.510677
# 8        Shooter     21.360790
# 10        Sports     13.812357
# 7   Role-Playing     13.375936
# 3           Misc      5.759657
# 4       Platform      3.908535
# 6         Racing      3.657318
# 2       Fighting      3.237400
# 1      Adventure      2.167435
# 9     Simulation      1.995067
# 11      Strategy      0.924186
# 5         Puzzle      0.290642

# %%
genre_trends = filtered_sales.groupby(['year_of_release', 'genre'])['total_sales'].sum().reset_index()

genre_trends_pivot = genre_trends.pivot(index='year_of_release', columns='genre', values='total_sales').fillna(0)

plt.figure(figsize=(14, 8))
genre_trends_pivot.plot(kind='line', linewidth=2, colormap='jet', figsize=(14, 8))

plt.title('Genre Growth or Decline Over Years', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Total Sales (in millions)', fontsize=12)
plt.legend(title='Genre', fontsize=10, loc='upper left')
plt.grid(alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment </h2>
#
# Nice chart! </div>

# %% [markdown]
# <div style="background-color: #e0e0e0; padding: 15px; border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid #a0a0a0;">
# <b> Dear Reviewer </b>
#
# I have tried so many different colormaps to be able to tell the difference between everything, but wanting to see the difference it all platforms,  what color scheme would you recommend using when working with large groups like this?</div>

# %% [markdown]
# ### Key Questions for Genre Analysis:
# - Which genres consistently perform well?
# - Are there any genres showing recent growth or decline?
# - How does the average performance vary across genres?

# %% [markdown]
# <div class="alert alert-block alert-info">
# <B> Conclusion: </B>
#
# * Action, shooter, and sports games took a majority of the sales market.
#     Action at 29.5% of the total sales
#     shooter at 21.4%
#     Sports at 13.8%
#
# * All games seem to have a decline especially after 2015.  Some games seem to come back up when a new game or new generation game/console come out at the same time.
#
# * Action games seem to dominate across all years.  as for Sports seems to have a high craze, and then a steep drop over time. Shooters seem to gradually stay a float above the rest other than Action games.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
#
# Is it possible that Action has made such volumes only due to the number of games? Maybe other genres have more sales per game unit. Consider doing the same but with median or average sales.
#
# </div>

# %% [markdown]
# <div style="background-color: #e0e0e0; padding: 15px; border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid #a0a0a0;">
# <b> Dear Reviewer </b>
#
# To better understand:
# the code would be to get the average of sales per latform and review it against the amount of games or average games sold per platform?
#
# do you need a correlation plot diagram for this as well?
# </div>

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3</h2>
#
#
# Yes, but we don't need the reviews. Take a look:
# </div>

# %%
# Reviewer's code 3

display(filtered_sales.groupby('genre')['total_sales'].sum().sort_values()[::-1])

filtered_sales.groupby('genre')['total_sales'].count().sort_values()[::-1]
# Out:
# genre
# Action          321.87
# Shooter         232.98
# Sports          150.65
# Role-Playing    145.89
# Misc             62.82
# Platform         42.63
# Racing           39.89
# Fighting         35.31
# Adventure        23.64
# Simulation       21.76
# Strategy         10.08
# Puzzle            3.17
# Name: total_sales, dtype: float64
# genre
# Action          766
# Role-Playing    292
# Adventure       245
# Sports          214
# Shooter         187
# Misc            155
# Racing           85
# Fighting         80
# Platform         74
# Simulation       62
# Strategy         56
# Puzzle           17
# Name: total_sales, dtype: int64

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3</h2>
#
#
# As you see, Action has 321 sum value and shooter has 332. However, Action has 766 games, while shooter has only 187. That means, Action has such a large sum volume only due to the large number of games. Shooter games has a comparable sum volume with a small number of games.
#
#
# What can be inferred here? A simple thing: we have to take into account the number of games. How can we do it? Take an average. Or median, as median will do approximately the same here.
#
#
#
# To sum up, we need create the same table but with mean or median.
#
# </div>

# %%
# Reviewer's code 3

filtered_sales.groupby('genre')['total_sales'].agg(['count', 'sum', 'mean', 'median']).sort_values(by='mean')[::-1]
# Out:
#               count     sum      mean  median
# genre
# Shooter         187  232.98  1.245882   0.450
# Sports          214  150.65  0.703972   0.240
# Platform         74   42.63  0.576081   0.225
# Role-Playing    292  145.89  0.499623   0.125
# Racing           85   39.89  0.469294   0.120
# Fighting         80   35.31  0.441375   0.125
# Action          766  321.87  0.420196   0.110
# Misc            155   62.82  0.405290   0.100
# Simulation       62   21.76  0.350968   0.100
# Puzzle           17    3.17  0.186471   0.060
# Strategy         56   10.08  0.180000   0.080
# Adventure       245   23.64  0.096490   0.030

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3</h2>
#
#
# Shooter games are more successful on average. Imagine we have 100 Action games, \\$1 each. We sell them all and receive \\$100. Let us also have 10 shooter games, \\$10 each. If we sell them, we are going to have another \\$100. What is better: 100 games for \\$1 each or 10 games \\$10 each? The second option is better. Imagine now that shooter games are \\$20. Of course we also need to take the development cost and complexity into account. The idea should be clear though :)
#
#
#
# </div>

# %% [markdown]
# # Step 4: Regional Market Analysis and User Profiles
#
# In this section, we will analyze the gaming market characteristics across three major regions: North America (NA), Europe (EU), and Japan (JP). Our analysis will focus on platform preferences, genre popularity, and the impact of ESRB ratings in each region.
#
# ## 4.1 Regional Platform Analysis
#
# Let's begin by examining platform performance across different regions:

# %%
# Function to analyze platform performance by region
# Analyze each region

# %%
recent_regional_study = filtered_sales[filtered_sales['year_of_release'] >= 2013]

NA_sales = recent_regional_study.groupby('platform')['na_sales'].sum().reset_index()
EU_sales = recent_regional_study.groupby('platform')['eu_sales'].sum().reset_index()
JP_sales = recent_regional_study.groupby('platform')['jp_sales'].sum().reset_index()
Other_sales = recent_regional_study.groupby('platform')['other_sales'].sum().reset_index()

merged_sales = NA_sales.merge(EU_sales, on='platform', suffixes=('_na', '_eu'))
merged_sales = merged_sales.merge(JP_sales, on='platform')
merged_sales = merged_sales.merge(Other_sales, on='platform')

merged_sales['total_sales'] = (
    merged_sales['na_sales'] + 
    merged_sales['eu_sales'] + 
    merged_sales['jp_sales'] + 
    merged_sales['other_sales']
)

merged_sales = merged_sales.sort_values(by='total_sales', ascending=False)

display(merged_sales)
# Out:
#    platform  na_sales  eu_sales  jp_sales  other_sales  total_sales
# 4       PS4    108.74    141.09     15.96        48.35       314.14
# 3       PS3     63.50     67.81     23.35        26.77       181.43
# 10     XOne     93.12     51.59      0.34        14.27       159.32
# 0       3DS     38.20     30.96     67.81         6.28       143.25
# 9      X360     81.66     42.52      0.51        12.11       136.80
# 8      WiiU     29.21     19.85     10.88         4.69        64.63
# 2        PC     11.11     25.36      0.00         2.96        39.43
# 6       PSV      5.04      6.10     18.59         3.26        32.99
# 7       Wii      6.56      5.93      0.05         1.12        13.66
# 5       PSP      0.00      0.17      3.29         0.04         3.50
# 1        DS      0.57      0.85      0.00         0.12         1.54

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3 </h2>
#
#
# Seems like people in Japan prefer portable platforms and japanese market. We definitely should not recommend them XBox :)
#
# </div>

# %% [markdown]
# ### Cross-Regional Platform Comparison
#
# Let's create a comparative analysis of platform performance across regions:

# %%
# Create a comparative platform analysis

# %%
na_sales = recent_regional_study.groupby('platform')['na_sales'].sum().reset_index()
eu_sales = recent_regional_study.groupby('platform')['eu_sales'].sum().reset_index()
jp_sales = recent_regional_study.groupby('platform')['jp_sales'].sum().reset_index()
other_sales = recent_regional_study.groupby('platform')['other_sales'].sum().reset_index()

platform_sales = na_sales.merge(eu_sales, on='platform', suffixes=('_na', '_eu'))
platform_sales = platform_sales.merge(jp_sales, on='platform')
platform_sales = platform_sales.merge(other_sales, on='platform')

platform_sales['total_sales'] = (
    platform_sales['na_sales'] +
    platform_sales['eu_sales'] +
    platform_sales['jp_sales'] +
    platform_sales['other_sales']
)

platform_sales = platform_sales.sort_values(by='total_sales', ascending=False)

top_platforms = platform_sales.head(5)
print(top_platforms)
# Out:
#    platform  na_sales  eu_sales  jp_sales  other_sales  total_sales
# 4       PS4    108.74    141.09     15.96        48.35       314.14
# 3       PS3     63.50     67.81     23.35        26.77       181.43
# 10     XOne     93.12     51.59      0.34        14.27       159.32
# 0       3DS     38.20     30.96     67.81         6.28       143.25
# 9      X360     81.66     42.52      0.51        12.11       136.80

# %%
# Visualize cross-regional comparison for top platforms

# %%
melted_sales = platform_sales.melt(
    id_vars='platform',
    value_vars=['na_sales', 'eu_sales', 'jp_sales', 'other_sales'],
    var_name='region',
    value_name='sales'
)

melted_sales = melted_sales[melted_sales['platform'].isin(top_platforms['platform'])]

plt.figure(figsize=(12, 8))
sns.barplot(data=melted_sales, x='sales', y='platform', hue='region', palette='Set2')

plt.title('Sales by Platform and Region', fontsize=16)
plt.xlabel('Sales (in millions)', fontsize=12)
plt.ylabel('Platform', fontsize=12)
plt.legend(title='Region', fontsize=10)

plt.show()

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3 </h2>
#
#
# Good!
# </div>

# %% [markdown]
# ## 4.2 Regional Genre Analysis
#
# Now let's examine genre preferences across regions:

# %%
# Function to analyze genre performance by region

# %%
def analyze_genre_performance_by_region(df):
   
    genre_sales_by_region = recent_regional_study.groupby('genre')[['na_sales', 'eu_sales', 'jp_sales', 'other_sales']].sum().reset_index()

    melted_genre_sales = genre_sales_by_region.melt(
        id_vars='genre',
        value_vars=['na_sales', 'eu_sales', 'jp_sales', 'other_sales'],
        var_name='region',
        value_name='sales'
    )

    plt.figure(figsize=(14, 8))
    sns.barplot(data=melted_genre_sales, x='sales', y='genre', hue='region', palette='Set2')
    plt.title('Genre Performance by Region', fontsize=16)
    plt.xlabel('Sales (in millions)', fontsize=12)
    plt.ylabel('Genre', fontsize=12)
    plt.legend(title='Region', fontsize=10)
    plt.tight_layout()
    plt.show()

analyze_genre_performance_by_region(df)

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3 </h2>
#
#
# For some reason, Japanese also don't like shooters as much as people in NA and EU do.
#
# </div>

# %% [markdown]
# ### Cross-Regional Genre Comparison
#
# Let's compare genre preferences across regions:

# %%
# Create a comparative genre analysis

# %% [markdown]
# <div class="alert alert-block alert-info">
# <B> Notes updated: </B>
#
# The top 3 best genres of recent years are:
#
#
# *    Action games had the best sales in NA, EU, and other,  While Role-Playing games had highest in JP
#
#
# *    shooter was 2nd highest in sales in the NA, EU, and other countries, as Action had 2nd highest sales in JP.
#
#
# *    lastly sports was 3rd highest is sales in NA, EU, and other countries, while misc placed 3rd in JP sales.
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
#
# Why 2004?
# </div>

# %% [markdown]
# ## 4.3 ESRB Rating Impact Analysis
#
# Finally, let's examine how ESRB ratings affect sales in each region:

# %%
# Function to analyze ESRB rating impact
# Analyze ESRB impact for each region

# %%
rating_sales = recent_regional_study.groupby('rating')[['na_sales', 'eu_sales', 'jp_sales', 'other_sales']].sum().reset_index()

melted_rating_sales = rating_sales.melt(
    id_vars='rating', 
    value_vars=['na_sales', 'eu_sales', 'jp_sales', 'other_sales'], 
    var_name='region', 
    value_name='sales'
)

plt.figure(figsize=(14, 8))
sns.barplot(data=melted_rating_sales, x='sales', y='rating', hue='region', palette='Set2')

plt.title('Sales by ESRB Rating and Region', fontsize=16)
plt.xlabel('Sales (in millions)', fontsize=12)
plt.ylabel('ESRB Rating', fontsize=12)

plt.legend(title='Region', fontsize=10)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b> Notes update: </b>
#
# After testing and plotting the ESRP rating and the effects on sales, I have come to the conclusion that based on the Genre, as well as ratings and country there are some key differences:
# *    NA - go for Mature rated, Action games, mostly on the PS4
# *    EU - go for Mature rated, Action games, mostly on the PS4
# *    Other - go for Mature rated, Action games, mostly on the PS4
# *    JP - go for Unkown or unrated , Role=Playing games, mostly on the 3DS
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3 </h2>
#
#
# Good! It's better to outline 2-3 platforms and genres so that decision makers have a choice.
# </div>   <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
#
# As a result, how do the regions differ? Would you please outline key difference between platform, genre and age rating distributions?
#
# </div>

# %% [markdown]
# # Step 5 : Hypothesis Tests
#
# —Average user ratings of the Xbox One and PC platforms are the same.
#
# —Average user ratings for the Action and Sports genres are different.
#
# Set the *alpha* threshold value yourself.
#
# Explain:
#
# —How you formulated the null and alternative hypotheses
#
# —What criteria you used to test the hypotheses~~,~~ and why

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2</h2>
#
#
# Good. The null hypothesis always includes the equality sign. This is because the test does not understand exactly how we set the problem: we can say, for instance, let's make sure that they are not equal. Or that they are equal. And regardless of the purpose of our study, we always put equality at null hypothesis. Then the test result is interpreted correctly.
#
# </div>

# %%
from scipy import stats

xbox_ratings = recent_regional_study[recent_regional_study['platform'] == 'XOne']['user_score'].astype(float)
pc_ratings = recent_regional_study[recent_regional_study['platform'] == 'PC']['user_score'].astype(float)

t_stat, p_value = stats.ttest_ind(xbox_ratings, pc_ratings, nan_policy='omit')

if p_value < 0.09:
    print("Reject H₀ (Null Hypothesis): The average user ratings for Xbox One and PC platforms are not the same.")
else:
    print("Fail to reject H₀ (Null Hypothesis): The average user ratings for Xbox One and PC platforms are the same.")
# Out:
# Fail to reject H₀ (Null Hypothesis): The average user ratings for Xbox One and PC platforms are the same.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b> Explanation! </b>
#
# * This T-Test is used to compare the means of two independent platforms by their ratings. The test is to see if there is a 9% difference between the user score on an Xbox and on PC. The test proved that the ratings are the same with no difference.
#     (I use 9% due to it shows larger differences in the ratings as well as it is my favorite number)
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 </h2>
#
#
# Correct. The time interval is also correct here.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment </h2>
#
#
# Platforms were chosen correctly!
# </div>

# %%
action_ratings = recent_regional_study[recent_regional_study['genre'] == 'Action']['user_score'].astype(float)
sports_ratings = recent_regional_study[recent_regional_study['genre'] == 'Sports']['user_score'].astype(float)

t_stat, p_value = stats.ttest_ind(action_ratings, sports_ratings)

if p_value < 0.09:
    print("Reject H₀ (Null Hypothesis): The average user ratings for Action and Sports genres are the same.")
else:
    print("Fail to reject H₀ (Null Hypothesis): The average user ratings for Action and Sports genres are not the same.")
# Out:
# Fail to reject H₀ (Null Hypothesis): The average user ratings for Action and Sports genres are not the same.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b> Explanation! </b>
#
# * This T-Test is used to compare the means of two independent Genres (Action & Sports) by their user scores.
#     The test is to see if there is a 9% difference between the user score in Action games and Sports games.
#     The test proved that the ratings are the same with no differences in their user score.
#     (I use 9% due to it shows larger differences in the ratings as well as it is my favorite number)
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 </h2>
#
#
# Good! </div>

# %% [markdown]
# # Step 6. Write a general conclusion

# %% [markdown]
# <div style="background-color: #d0e6f5; border: 2px solid #b0cfe4; padding: 20px; border-radius: 5px;">
#     <b> FINAL CONCLUSION! Updated</b>
#     <p>
#         After looking through the gaming sales for 2017 and analyzing the data to come up with best marketing strategies.
#     </p>
#     <p>
#         In NA - Gamers generally go for Mature rated, Action games, mostly playing on the PS4
#         In EU - Gamers go for Mature rated, Action games, mostly playing on the PS4
#         In Other - Gamers go for Mature rated, Action games, mostly playing on the PS4
#         In JP - Gamers go for Unkown or unrated games, Role-Playing games, mostly on the 3DS
#     </p>
#     <p>
#         Gamers also tend to go towards what they are used to. For example: Call of Duty. With each release of the sequel, even on the same platform, gamers were excited and ratings were high.
#         Even though it is virtually the same game, just new experiences, new maps, new guns, new looks.
#     </p>
#     <b> Thoughts: </b>
#     <p>
#         In 2017, I believe that it would be wise to come out with a new Action game
#         <P>
#         (in all countries but JP, as i would recommend a Role playing game on the 3DS)
#         <P>
#             (bonus if it is a shooter and has some sports mixed in).
#             </P>
#             </P>
#         Not only should this new game be available on the latest generation platforms, but also making it cross-platform and allowing it to be added to.
#         Coming out with a game that is ever-changing, a new experience every time you play, and giving the ability for backward compatibility or the ability to transition data.
#         Other games to consider are sequels of games that everyone loves: Call of Duty, GTA, Super Smash Brothers, The Elder Scrolls, Mortal Kombat, etc.
#     </p>
#     <p>
#         (Coming from a gamer, I have played a game where it came out on the next generation, but I could not load my file into the new generation as it was not backward compatible, so I needed to start all over again.)
#     </p>
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3 </h2>
#
#
# Perfect!
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2</h2>
#
#
# Well done! </div>
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2</h2>
#
# However, please add key results: add a list of promising platforms and more information about each of the regions: 2-3 platforms, 2-3 genres and age ratings.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment</h2>
#
#
# The conclusion is written well.
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment</h2>
#
# You can also add recommendations.
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment</h2>
#
# It will be great if you add a list of promising platforms and more information about each of the regions: 2-3 platforms, 2-3 genres and age ratings.
#
#
# If we look at the task description, we will see tha phrase "Let’s imagine that it’s December 2016 and you’re planning a campaign for 2017." so 2004 may not be that relevant if our final goal is to make predictions for 2017.
# </div>
